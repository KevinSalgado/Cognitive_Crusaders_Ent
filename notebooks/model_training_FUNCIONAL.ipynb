# %%
# %pip install skforecast
# Out:
# Collecting skforecast
#   Downloading skforecast-0.8.1-py2.py3-none-any.whl (386 kB)
#      |████████████████████████████████| 386 kB 1.7 MB/s eta 0:00:01
# Requirement already satisfied: joblib<1.3.0,>=1.1.0 in /home/pc/anaconda3/lib/python3.9/site-packages (from skforecast) (1.1.0)
# Requirement already satisfied: pandas<2.1,>=1.2 in /home/pc/anaconda3/lib/python3.9/site-packages (from skforecast) (1.3.4)
# Requirement already satisfied: numpy<1.25,>=1.20 in /home/pc/anaconda3/lib/python3.9/site-packages (from skforecast) (1.20.3)
# Collecting scikit-learn<1.3,>=1.0
#   Downloading scikit_learn-1.2.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.6 MB)
#      |████████████████████████████████| 9.6 MB 4.7 MB/s eta 0:00:011
# Requirement already satisfied: tqdm<4.65,>=4.57.0 in /home/pc/anaconda3/lib/python3.9/site-packages (from skforecast) (4.62.3)
# Collecting optuna<3.2,>=2.10.0
#   Downloading optuna-3.1.1-py3-none-any.whl (365 kB)
#      |████████████████████████████████| 365 kB 7.1 MB/s eta 0:00:01
# Collecting alembic>=1.5.0
#   Downloading alembic-1.11.1-py3-none-any.whl (224 kB)
#      |████████████████████████████████| 224 kB 6.9 MB/s eta 0:00:01
# Requirement already satisfied: PyYAML in /home/pc/anaconda3/lib/python3.9/site-packages (from optuna<3.2,>=2.10.0->skforecast) (6.0)
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Collecting cmaes>=0.9.1
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /home/pc/anaconda3/lib/python3.9/site-packages (from optuna<3.2,>=2.10.0->skforecast) (1.4.22)
# Requirement already satisfied: packaging>=20.0 in /home/pc/anaconda3/lib/python3.9/site-packages (from optuna<3.2,>=2.10.0->skforecast) (21.0)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 5.1 MB/s eta 0:00:011
# Collecting typing-extensions>=4
#   Downloading typing_extensions-4.6.2-py3-none-any.whl (31 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/pc/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->optuna<3.2,>=2.10.0->skforecast) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/pc/anaconda3/lib/python3.9/site-packages (from pandas<2.1,>=1.2->skforecast) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/pc/anaconda3/lib/python3.9/site-packages (from pandas<2.1,>=1.2->skforecast) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/pc/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas<2.1,>=1.2->skforecast) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/pc/anaconda3/lib/python3.9/site-packages (from scikit-learn<1.3,>=1.0->skforecast) (2.2.0)
# Collecting joblib<1.3.0,>=1.1.0
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      |████████████████████████████████| 297 kB 6.9 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.3.2 in /home/pc/anaconda3/lib/python3.9/site-packages (from scikit-learn<1.3,>=1.0->skforecast) (1.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in /home/pc/anaconda3/lib/python3.9/site-packages (from sqlalchemy>=1.3.0->optuna<3.2,>=2.10.0->skforecast) (1.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/pc/anaconda3/lib/python3.9/site-packages (from Mako->alembic>=1.5.0->optuna<3.2,>=2.10.0->skforecast) (1.1.1)
# Installing collected packages: typing-extensions, Mako, joblib, colorlog, cmaes, alembic, scikit-learn, optuna, skforecast
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.2
#     Uninstalling scikit-learn-0.24.2:
#       Successfully uninstalled scikit-learn-0.24.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.4.1 requires flatbuffers~=1.12.0, but you have flatbuffers 2.0 which is incompatible.
# tensorflow 2.4.1 requires gast==0.3.3, but you have gast 0.4.0 which is incompatible.
# tensorflow 2.4.1 requires grpcio~=1.32.0, but you have grpcio 1.42.0 which is incompatible.
# tensorflow 2.4.1 requires numpy~=1.19.2, but you have numpy 1.20.3 which is incompatible.
# tensorflow 2.4.1 requires six~=1.15.0, but you have six 1.16.0 which is incompatible.
# tensorflow 2.4.1 requires tensorflow-estimator<2.5.0,>=2.4.0, but you have tensorflow-estimator 2.6.0 which is incompatible.
# tensorflow 2.4.1 requires typing-extensions~=3.7.4, but you have typing-extensions 4.6.2 which is incompatible.
# Successfully installed Mako-1.2.4 alembic-1.11.1 cmaes-0.9.1 colorlog-6.7.0 joblib-1.2.0 optuna-3.1.1 scikit-learn-1.2.2 skforecast-0.8.1 typing-extensions-4.6.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade typing extensions
# Out:
# Collecting typing
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 1.5 MB/s eta 0:00:01
# Collecting extensions
#   Downloading extensions-0.4.tar.gz (16 kB)
# Building wheels for collected packages: typing, extensions
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26324 sha256=285f5c9ac2636855abdcab9049635dec838ca30d5a567f100b4cfdefdf1fd570
#   Stored in directory: /home/pc/.cache/pip/wheels/fa/17/1f/332799f975d1b2d7f9b3f33bbccf65031e794717d24432caee
#   Building wheel for extensions (setup.py) ... done
#   Created wheel for extensions: filename=extensions-0.4-py3-none-any.whl size=16387 sha256=9656a5dcee5aa6aa43d80ab75379d50948d5a5906a03e3d9bd5d2af2e6b616b5
#   Stored in directory: /home/pc/.cache/pip/wheels/26/fd/ba/404b849f22380952092f9863451135416a5b615095bb2e1c8e
# Successfully built typing extensions
# Installing collected packages: typing, extensions
# Successfully installed extensions-0.4 typing-3.7.4.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /home/pc/anaconda3/lib/python3.9/site-packages (21.2.4)
# Collecting pip
#   Downloading pip-23.1.2-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 1.7 MB/s eta 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.4
#     Uninstalling pip-21.2.4:
#       Successfully uninstalled pip-21.2.4
# Successfully installed pip-23.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade skforecast
# Out:
# Requirement already satisfied: skforecast in /home/pc/anaconda3/lib/python3.9/site-packages (0.8.1)
# Requirement already satisfied: numpy<1.25,>=1.20 in /home/pc/anaconda3/lib/python3.9/site-packages (from skforecast) (1.20.3)
# Requirement already satisfied: pandas<2.1,>=1.2 in /home/pc/anaconda3/lib/python3.9/site-packages (from skforecast) (1.3.4)
# Requirement already satisfied: tqdm<4.65,>=4.57.0 in /home/pc/anaconda3/lib/python3.9/site-packages (from skforecast) (4.62.3)
# Requirement already satisfied: scikit-learn<1.3,>=1.0 in /home/pc/anaconda3/lib/python3.9/site-packages (from skforecast) (1.2.2)
# Requirement already satisfied: optuna<3.2,>=2.10.0 in /home/pc/anaconda3/lib/python3.9/site-packages (from skforecast) (3.1.1)
# Requirement already satisfied: joblib<1.3.0,>=1.1.0 in /home/pc/anaconda3/lib/python3.9/site-packages (from skforecast) (1.2.0)
# Requirement already satisfied: alembic>=1.5.0 in /home/pc/anaconda3/lib/python3.9/site-packages (from optuna<3.2,>=2.10.0->skforecast) (1.11.1)
# Requirement already satisfied: cmaes>=0.9.1 in /home/pc/anaconda3/lib/python3.9/site-packages (from optuna<3.2,>=2.10.0->skforecast) (0.9.1)
# Requirement already satisfied: colorlog in /home/pc/anaconda3/lib/python3.9/site-packages (from optuna<3.2,>=2.10.0->skforecast) (6.7.0)
# Requirement already satisfied: packaging>=20.0 in /home/pc/anaconda3/lib/python3.9/site-packages (from optuna<3.2,>=2.10.0->skforecast) (21.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /home/pc/anaconda3/lib/python3.9/site-packages (from optuna<3.2,>=2.10.0->skforecast) (1.4.22)
# Requirement already satisfied: PyYAML in /home/pc/anaconda3/lib/python3.9/site-packages (from optuna<3.2,>=2.10.0->skforecast) (6.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/pc/anaconda3/lib/python3.9/site-packages (from pandas<2.1,>=1.2->skforecast) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/pc/anaconda3/lib/python3.9/site-packages (from pandas<2.1,>=1.2->skforecast) (2021.3)
# Requirement already satisfied: scipy>=1.3.2 in /home/pc/anaconda3/lib/python3.9/site-packages (from scikit-learn<1.3,>=1.0->skforecast) (1.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/pc/anaconda3/lib/python3.9/site-packages (from scikit-learn<1.3,>=1.0->skforecast) (2.2.0)
# Requirement already satisfied: Mako in /home/pc/anaconda3/lib/python3.9/site-packages (from alembic>=1.5.0->optuna<3.2,>=2.10.0->skforecast) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in /home/pc/anaconda3/lib/python3.9/site-packages (from alembic>=1.5.0->optuna<3.2,>=2.10.0->skforecast) (4.6.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/pc/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->optuna<3.2,>=2.10.0->skforecast) (3.0.4)
# Requirement already satisfied: six>=1.5 in /home/pc/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas<2.1,>=1.2->skforecast) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/pc/anaconda3/lib/python3.9/site-packages (from sqlalchemy>=1.3.0->optuna<3.2,>=2.10.0->skforecast) (1.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/pc/anaconda3/lib/python3.9/site-packages (from Mako->alembic>=1.5.0->optuna<3.2,>=2.10.0->skforecast) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Gráficos
# ==============================================================================
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
plt.rcParams['lines.linewidth'] = 1.5

# Modelado y Forecasting
# ==============================================================================
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

from skforecast.ForecasterAutoreg import ForecasterAutoreg
from skforecast.ForecasterAutoregCustom import ForecasterAutoregCustom
from skforecast.ForecasterAutoregDirect import ForecasterAutoregDirect
from skforecast.model_selection import grid_search_forecaster
from skforecast.model_selection import backtesting_forecaster
from skforecast.utils import save_forecaster
from skforecast.utils import load_forecaster

# %% [markdown]
# # **Import CSV data**

# %%
# Paths
abonado_path = '../data/abonado.csv'
cliente_path = '../data/cliente.csv'
contador_path = '../data/contador.csv'
caudales_path = '../data/caudales.csv'
gis_path = '../data/gis.csv'
clima_path = '../data/clima.csv'

# %%
df_abonado = pd.read_csv(abonado_path)
df_cliente = pd.read_csv(cliente_path)
df_contador = pd.read_csv(contador_path)
df_caudales = pd.read_csv(caudales_path)
df_gis = pd.read_csv(gis_path)
df_clima = pd.read_csv(clima_path)

# %% [markdown]
# # **Prediction Class**

# %% [markdown]
# La función **transf** transforma limpia y junta los datos de un sector contando las fechas de 2021 y 2022

# %%
def transf (Sector: int, dataframe : pd.DataFrame=None):
    #clima_path = '../../Workspace/General Docs shared folder/setDatos/clima.csv'
    #df_clima = pd.read_csv(clima_path)

    # Si el dataframe a insertar esta vacío entonces se inserta solo
    if dataframe is None:
        #caudales_path = '../../Workspace/General Docs shared folder/setDatos/caudales.csv'
        dataframe = df_caudales #pd.read_csv(caudales_path)

    # Filtramos por Sector
    dataframe = dataframe.loc[(dataframe["Canonical"]=="CAUDAL") & (dataframe["Sector_Neta"]==Sector)]

    print("Tamaño: ",dataframe.shape)

    # Extraemos la fecha aparte #################### CHECAR LA FECHA QUE VIENE AHÍ MARCADA #######################
    dataframe['fecha'] = dataframe['RowKey'].str.extract('([0-9]{4}-[0-9]{2}-[0-9]{2})') #########################
    #dataframe = dataframe.loc[(dataframe["fecha"].str.startswith(Fecha))]
    
    print(dataframe.info())

    print("Tamaño despues de filtrar: ", dataframe.shape)

    # Extraemos la hora aparte #################### CHECAR LA HORA QUE VIENE AHÍ MARCADA #######################
    dataframe['hora']=dataframe['RowKey'].str.extract('([0-9]{2}:[0-9]{2}:[0-9]{2})') ##########################

    # Convertimos la fecha en formato date
    dataframe['fecha'] = pd.to_datetime(dataframe['fecha'])

    print("CheckPoint: Date")

    # Hacemos limpieza de los datos del clima que no necesitaremos
    df_clima_clean = df_clima.drop(columns = [
        "wdir","maxt","visibility","wspd","solarenergy","heatindex","cloudcover","mint","datetime","precip","solarradiation",
        "weathertype","snowdepth","sealevelpressure","snow","dew","precipcover","wgust","conditions","windchill","info","locations"])

    # Sacamos la fecha en una columna diferente
    df_clima_clean['fecha'] = df_clima_clean['datetimeStr'].str.extract('([0-9]{4}-[0-9]{2}-[0-9]{2})') #############
    
    # Le ponemos el formato de datetime a la fecha
    df_clima_clean['fecha'] = pd.to_datetime(df_clima_clean['fecha'])
    
    # Sacamos el promedio por fecha de la temperatura y humedad
    df_clima_agrup = df_clima_clean.groupby(["fecha"]).mean()
    
    # Quitamos los index
    df_clima_agrup.reset_index()

    # Juntamos la fecha de los caudales con la del clima
    dataframe = pd.merge(df_clima_agrup,dataframe, on="fecha")

    # Dividimos la fecha en año, mes, dia, dia_semana
    dataframe['ano'] = dataframe['fecha'].dt.year ################################################################
    dataframe['mes'] = dataframe['fecha'].dt.month
    dataframe['dia'] = dataframe['fecha'].dt.day
    dataframe['dia_semana'] = dataframe['fecha'].dt.weekday

    # Renombramos las columnas
    dataframe = dataframe.rename(columns = {"INF_Values":"DATOS","fecha":"FECHA", "hora":"HORA", "ano":"AÑO","mes":"MES","dia":"DIA","dia_semana":"DIA_SEMANA"})

    # Convertimos la hora en formato de fecha
    dataframe['HORA'] = pd.to_datetime(dataframe['HORA'])

    # Sacamos la hora y minuto de la columna hora
    dataframe['HORA_NUMERICA'] = pd.to_datetime(dataframe['HORA'], format='%H:%M:%S').dt.hour
    dataframe['MINUTO_NUMERICO'] = pd.to_datetime(dataframe['HORA'], format='%H:%M:%S').dt.minute

    # Eliminamos las columnas que no nos interesa para los datos
    dataframe = dataframe.drop(columns = (["Canonical","RowKey","INF_Label","STA_Label","Sector_Neta","FECHA","HORA"]))
    dataframe = dataframe.rename(columns= {"INF_Value":"DATO","temp":"TEMP","humidity":"HUMEDAD"})

    # Eliminamos los datos 0 
    dataframe = dataframe.drop(dataframe[(dataframe['DATO'] == 0)].index)

    return dataframe

# %% [markdown]
# A continuación se presenta una clase diseñada que permite realizar todas las tareas de limpieza, entrenamiento y predicción para un sector específico.

# %%
# Class
class PredictWaterConsume(object):
    def __init__(self, sector_num):
        self.df_sector = pd.DataFrame(transf(sector_num,))
        self.create_date()
        #df_sector.head()


    def create_date(self):
        X_prueba = self.df_sector.copy()
        X_prueba['FECHA'] = X_prueba['AÑO'].astype(str) + "-"+X_prueba['MES'].astype(str) +"-"+ X_prueba['DIA'].astype(str) + " " + X_prueba['HORA_NUMERICA'].astype(str) + ":" + X_prueba['MINUTO_NUMERICO'].astype(str)
        X_prueba['FECHA'] = pd.to_datetime(X_prueba['FECHA'])
        df_sector_temphum = X_prueba
        #df_sector_temphum.head()

        data = df_sector_temphum.set_index('FECHA')
        self.data = data.sort_index()
        #data
        #self.data = data.asfreq('MS')

        
    ### CHECAR ESA FUNCIÓN PORQUE DE AQUÍ DEPENDE LA SEPARACIÓN DE TEST, TRAIN ###
    def subset_mes(self, year, month):
        # Subset de datos (mes)
        self.subset = self.data[(self.data.index.strftime('%Y-%m').str.startswith('{}-{}'.format(year, month)))]
        #df_cau_agosto
        self.subset = self.subset.drop(["AÑO","MES","DIA","DIA_SEMANA","HORA_NUMERICA","MINUTO_NUMERICO"], axis=1)

    def train(self, steps=900, _lags_=144):
        # Separación datos train-test
        # ==============================================================================
        #steps = 900
        self.datos_train = self.subset[:-steps]
        self.datos_test  = self.subset[-steps:]

        print(f"Fechas train : {self.datos_train.index.min()} --- {self.datos_train.index.max()}  (n={len(self.datos_train)})")
        print(f"Fechas test  : {self.datos_test.index.min()} --- {self.datos_test.index.max()}  (n={len(self.datos_test)})")

        fig, ax = plt.subplots(figsize=(7, 3))
        self.datos_train['DATO'].plot(ax=ax, label='train')
        self.datos_test['DATO'].plot(ax=ax, label='test')
        ax.legend();

        # Crear y entrenar forecaster
        # ==============================================================================
        self.forecaster = ForecasterAutoreg(
                        regressor = RandomForestRegressor(),
                        lags = _lags_ # 144
                    )
        y = self.datos_train['DATO']
        self.forecaster.fit(y)
        #forecaster


    def predict(self, steps=900):
        # Predicciones
        # ==============================================================================
        #steps = 900
        predicciones = self.forecaster.predict(steps=steps)
        predicciones.head(5)

        predicciones.index = pd.Index(self.datos_test.index)

        predicciones.head()


        # Gráfico Predicciones
        # ==============================================================================
        fig, ax = plt.subplots(figsize=(15, 8))
        self.datos_train['DATO'].plot(ax=ax, label='train')
        self.datos_test['DATO'].plot(ax=ax, label='test')
        predicciones.plot(ax=ax, label='predicciones')
        ax.legend();

        return predicciones


    def get_error():
        # Error test
        # ==============================================================================
        error_mse = mean_squared_error(
                        y_true = datos_test['DATO'],
                        y_pred = predicciones
                    )

        print(f"Error de test (mse): {error_mse}")

        error_r2_score = r2_score(
                        y_true = datos_test['DATO'],
                        y_pred = predicciones
        )
        print(f"r2_score: {error_r2_score}")

# %% [markdown]
# ## Prueba con Valladolid

# %%
# Crea objeto y limpia datos
obj = PredictWaterConsume(22120000)
# subset
obj.subset_mes('2021', '08')
# Out:
# Tamaño:  (47534, 6)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47534 entries, 21933 to 941387
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Canonical    47534 non-null  object
#  1   RowKey       47534 non-null  object
#  2   INF_Label    47534 non-null  object
#  3   INF_Value    47534 non-null  float64
#  4   STA_Label    47534 non-null  object
#  5   Sector_Neta  47534 non-null  int64
#  6   fecha        47534 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 2.9+ MB
# None
# Tamaño despues de filtrar:  (47534, 7)
# /tmp/ipykernel_6985/2786759899.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['fecha'] = dataframe['RowKey'].str.extract('([0-9]{4}-[0-9]{2}-[0-9]{2})') #########################
# /tmp/ipykernel_6985/2786759899.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['hora']=dataframe['RowKey'].str.extract('([0-9]{2}:[0-9]{2}:[0-9]{2})') ##########################
# /tmp/ipykernel_6985/2786759899.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['fecha'] = pd.to_datetime(dataframe['fecha'])
# CheckPoint: Date

# %%
obj.train()
# Out:
# Fechas train : 2021-08-01 00:15:00 --- 2021-08-22 14:45:00  (n=2075)
# Fechas test  : 2021-08-22 15:00:00 --- 2021-08-31 23:45:00  (n=900)
# /home/pc/anaconda3/lib/python3.9/site-packages/skforecast/utils/utils.py:791: UserWarning: `y` has DatetimeIndex index but no frequency. Index is overwritten with a RangeIndex of step 1.
#   warnings.warn(
# /home/pc/anaconda3/lib/python3.9/site-packages/skforecast/utils/utils.py:791: UserWarning: `y` has DatetimeIndex index but no frequency. Index is overwritten with a RangeIndex of step 1.
#   warnings.warn(

# %%
obj.predict()
# Out:
# /home/pc/anaconda3/lib/python3.9/site-packages/skforecast/utils/utils.py:854: UserWarning: `last_window` has DatetimeIndex index but no frequency. Index is overwritten with a RangeIndex of step 1.
#   warnings.warn(
# FECHA
# 2021-08-22 15:00:00    54.060001
# 2021-08-22 15:15:00    53.340001
# 2021-08-22 15:30:00    51.844001
# 2021-08-22 15:45:00    49.864001
# 2021-08-22 16:00:00    48.460001
#                          ...
# 2021-08-31 22:45:00    54.964001
# 2021-08-31 23:00:00    51.924001
# 2021-08-31 23:15:00    48.988001
# 2021-08-31 23:30:00    46.208001
# 2021-08-31 23:45:00    44.180001
# Name: pred, Length: 900, dtype: float64

# %%
# the model is the "self.forecaster"

# %% [markdown]
# # **Save model**

# %%
import pickle

# %%
# save the model to disk
filename = 'valladolid_model.sav'
pickle.dump(obj.forecaster, open(filename, 'wb'))

# %% [markdown]
# ### REVISAR BIEN PARA QUE QUEDE CORRECTO

# %%
# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))

# %%
obj.datos_test[:20].shape
# Out:
# (20, 3)

# %%
def predict(steps=900):
    # Predicciones
    # ==============================================================================
    #steps = 900
    predicciones = loaded_model.predict(steps=steps)
    predicciones.head(5)

    predicciones.index = pd.Index(obj.datos_test.index)
    #predicciones.head()


    # Gráfico Predicciones
    # ==============================================================================
    fig, ax = plt.subplots(figsize=(15, 8))
    obj.datos_train['DATO'].plot(ax=ax, label='train')
    obj.datos_test['DATO'].plot(ax=ax, label='test')
    predicciones.plot(ax=ax, label='predicciones')
    ax.legend();

    return predicciones

# %%
aa = predict(20)
aa.index = pd.Index(obj.datos_test[:20].index)
aa.head()
# Out:
# /home/pc/anaconda3/lib/python3.9/site-packages/skforecast/utils/utils.py:854: UserWarning: `last_window` has DatetimeIndex index but no frequency. Index is overwritten with a RangeIndex of step 1.
#   warnings.warn(
# FECHA
# 2021-08-22 15:00:00    54.060001
# 2021-08-22 15:15:00    53.340001
# 2021-08-22 15:30:00    51.844001
# 2021-08-22 15:45:00    49.864001
# 2021-08-22 16:00:00    48.460001
# Name: pred, dtype: float64

# %%
obj.datos_test[:10].index
# Out:
# DatetimeIndex(['2021-08-22 15:00:00', '2021-08-22 15:15:00',
#                '2021-08-22 15:30:00', '2021-08-22 15:45:00',
#                '2021-08-22 16:00:00', '2021-08-22 16:15:00',
#                '2021-08-22 16:30:00', '2021-08-22 16:45:00',
#                '2021-08-22 17:00:00', '2021-08-22 17:15:00'],
#               dtype='datetime64[ns]', name='FECHA', freq=None)

# %%
predict()
# Out:
# /home/pc/anaconda3/lib/python3.9/site-packages/skforecast/utils/utils.py:854: UserWarning: `last_window` has DatetimeIndex index but no frequency. Index is overwritten with a RangeIndex of step 1.
#   warnings.warn(
# FECHA
# 2021-08-22 15:00:00    54.060001
# 2021-08-22 15:15:00    53.340001
# 2021-08-22 15:30:00    51.844001
# 2021-08-22 15:45:00    49.864001
# 2021-08-22 16:00:00    48.460001
#                          ...
# 2021-08-31 22:45:00    54.964001
# 2021-08-31 23:00:00    51.924001
# 2021-08-31 23:15:00    48.988001
# 2021-08-31 23:30:00    46.208001
# 2021-08-31 23:45:00    44.180001
# Name: pred, Length: 900, dtype: float64

# %%
obj.datos_train.shape
# Out:
# (2075, 3)

# %%
obj.datos_test.shape
# Out:
# (900, 3)

# %% [markdown]
# **Tiempo de Predicción | Steps Train**
# <br>1 día   =
# <br>3 días  =
# <br>11 días =

# %% [markdown]
# ## DESCUBRIENDO LAS FECHAS QUE SE PUEDEN PREDECIR SIN SEPARAR POR MESES

# %%
# Class
class PredictWaterConsumeMMM(object):
    def __init__(self, sector_num):
        self.df_sector = pd.DataFrame(transf(sector_num,))
        self.create_date()
        #df_sector.head()


    def create_date(self):
        X_prueba = self.df_sector.copy()
        X_prueba['FECHA'] = X_prueba['AÑO'].astype(str) + "-"+X_prueba['MES'].astype(str) +"-"+ X_prueba['DIA'].astype(str) + " " + X_prueba['HORA_NUMERICA'].astype(str) + ":" + X_prueba['MINUTO_NUMERICO'].astype(str)
        X_prueba['FECHA'] = pd.to_datetime(X_prueba['FECHA'])
        df_sector_temphum = X_prueba
        #df_sector_temphum.head()

        data = df_sector_temphum.set_index('FECHA')
        self.data = data.sort_index()
        #data
        #self.data = data.asfreq('MS')

        
    ### CHECAR ESA FUNCIÓN PORQUE DE AQUÍ DEPENDE LA SEPARACIÓN DE TEST, TRAIN ###
    #def subset_mes(self, year, month):
        # Subset de datos (mes)
    #    self.subset = self.data[(self.data.index.strftime('%Y-%m').str.startswith('{}-{}'.format(year, month)))]
        #df_cau_agosto
    #    self.subset = self.subset.drop(["AÑO","MES","DIA","DIA_SEMANA","HORA_NUMERICA","MINUTO_NUMERICO"], axis=1)

    def split_data(self, steps=900):
        self.datos_train = self.data[:-steps].drop(["AÑO","MES","DIA","DIA_SEMANA","HORA_NUMERICA","MINUTO_NUMERICO"], axis=1)
        self.datos_test  = self.data[-steps:].drop(["AÑO","MES","DIA","DIA_SEMANA","HORA_NUMERICA","MINUTO_NUMERICO"], axis=1)        
    
    def train(self, steps=900, _lags_=144):
        # Separación datos train-test
        # ==============================================================================
        #steps = 900
        ##self.datos_train = self.data[:-steps]
        ##self.datos_test  = self.data[-steps:]

        print(f"Fechas train : {self.datos_train.index.min()} --- {self.datos_train.index.max()}  (n={len(self.datos_train)})")
        print(f"Fechas test  : {self.datos_test.index.min()} --- {self.datos_test.index.max()}  (n={len(self.datos_test)})")

        fig, ax = plt.subplots(figsize=(7, 3))
        self.datos_train['DATO'].plot(ax=ax, label='train')
        self.datos_test['DATO'].plot(ax=ax, label='test')
        ax.legend();

        # Crear y entrenar forecaster
        # ==============================================================================
        self.forecaster = ForecasterAutoreg(
                        regressor = RandomForestRegressor(),
                        lags = _lags_ # 144
                    )
        y = self.datos_train['DATO']
        self.forecaster.fit(y)
        #forecaster


    def predict(self, steps=900):
        # Predicciones
        # ==============================================================================
        #steps = 900
        predicciones = self.forecaster.predict(steps=steps)
        predicciones.head(5)

        
        sub = self.datos_test['DATO'][:steps] ################################################
        predicciones.index = pd.Index(sub.index) ######################################

        predicciones.head()


        # Gráfico Predicciones
        # ==============================================================================
        fig, ax = plt.subplots(figsize=(15, 8))
        self.datos_train['DATO'][-steps:].plot(ax=ax, label='train')
        sub.plot(ax=ax, label='test')
        predicciones.plot(ax=ax, label='predicciones')
        ax.legend();

        return predicciones
 
    def get_error():
        # Error test
        # ==============================================================================
        error_mse = mean_squared_error(
                        y_true = datos_test['DATO'],
                        y_pred = predicciones
                    )

        print(f"Error de test (mse): {error_mse}")

        error_r2_score = r2_score(
                        y_true = datos_test['DATO'],
                        y_pred = predicciones
        )
        print(f"r2_score: {error_r2_score}")

# %%
mm = PredictWaterConsumeMMM(22120000)
# Out:
# Tamaño:  (47534, 6)
# /tmp/ipykernel_6985/2786759899.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['fecha'] = dataframe['RowKey'].str.extract('([0-9]{4}-[0-9]{2}-[0-9]{2})') #########################
# /tmp/ipykernel_6985/2786759899.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['hora']=dataframe['RowKey'].str.extract('([0-9]{2}:[0-9]{2}:[0-9]{2})') ##########################
# /tmp/ipykernel_6985/2786759899.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['fecha'] = pd.to_datetime(dataframe['fecha'])
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47534 entries, 21933 to 941387
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Canonical    47534 non-null  object
#  1   RowKey       47534 non-null  object
#  2   INF_Label    47534 non-null  object
#  3   INF_Value    47534 non-null  float64
#  4   STA_Label    47534 non-null  object
#  5   Sector_Neta  47534 non-null  int64
#  6   fecha        47534 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 2.9+ MB
# None
# Tamaño despues de filtrar:  (47534, 7)
# CheckPoint: Date

# %%
mm.split_data(21988)

# %%
print(mm.datos_train.shape)
print(mm.datos_test.shape)
# Out:
# (23540, 3)
# (21988, 3)

# %%
mm.datos_test.head() # podemos predecir desde el 3 de abril hasta el último día del año 2022
# Out:
#                          TEMP    HUMEDAD  DATO
# FECHA
# 2022-04-04 00:00:00  8.466667  60.563333  25.6
# 2022-04-04 00:15:00  8.466667  60.563333  22.0
# 2022-04-04 00:30:00  8.466667  60.563333  22.0
# 2022-04-04 00:45:00  8.466667  60.563333  20.8
# 2022-04-04 01:00:00  8.466667  60.563333  20.4

# %%
mm.train()
# Out:
# Fechas train : 2021-08-01 00:15:00 --- 2022-04-03 20:45:00  (n=23528)
# Fechas test  : 2022-04-03 21:00:00 --- 2022-12-12 06:00:00  (n=22000)
# /home/pc/anaconda3/lib/python3.9/site-packages/skforecast/utils/utils.py:791: UserWarning: `y` has DatetimeIndex index but no frequency. Index is overwritten with a RangeIndex of step 1.
#   warnings.warn(
# /home/pc/anaconda3/lib/python3.9/site-packages/skforecast/utils/utils.py:791: UserWarning: `y` has DatetimeIndex index but no frequency. Index is overwritten with a RangeIndex of step 1.
#   warnings.warn(

# %%
pp = mm.predict(steps=100)
# Out:
# /home/pc/anaconda3/lib/python3.9/site-packages/skforecast/utils/utils.py:854: UserWarning: `last_window` has DatetimeIndex index but no frequency. Index is overwritten with a RangeIndex of step 1.
#   warnings.warn(

# %%
pp2 = mm.predict(steps=900)
# Out:
# /home/pc/anaconda3/lib/python3.9/site-packages/skforecast/utils/utils.py:854: UserWarning: `last_window` has DatetimeIndex index but no frequency. Index is overwritten with a RangeIndex of step 1.
#   warnings.warn(

# %%
pp3 = mm.predict(steps=2000)
# Out:
# /home/pc/anaconda3/lib/python3.9/site-packages/skforecast/utils/utils.py:854: UserWarning: `last_window` has DatetimeIndex index but no frequency. Index is overwritten with a RangeIndex of step 1.
#   warnings.warn(

# %%
# HACER EL CÁLCULO DE CUÁNTOS STEPS SON POR DÍA O DÍAS
# 96 * num_dias + 16 (las 16 son de las últimas horas del 3 de abril) ------ cuadno split 22000
